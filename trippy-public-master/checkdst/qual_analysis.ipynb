# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from qual_analysis_utils import get_pred_dfs

# %%
main_dir = "results/of_interest"

# %%
pred_res = get_pred_dfs(main_dir, inv="NEI", step="4732")

# %%
len(pred_res), len(pred_res[0])
# Out:
# (5, 7372)

# %%
# keep only those for which their predictions agree

# %%
pred_res[1] == pred_res[0] == pred_res[2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_71036/3783374012.py in <module>
# ----> 1 pred_res[1] == pred_res[0] == pred_res[2]
#
# ~/miniconda/envs/trippy/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import pandas as pd

# %%
merged = pd.merge(pred_res[1], pred_res[0]).merge(pred_res)

# %%
merged
# Out:
#                   id  ... train-departure_pred
# 0     mul0003.json-0  ...                 none
# 1     mul0003.json-1  ...                 none
# 2     mul0011.json-0  ...                 none
# 3     mul0011.json-1  ...                 none
# 4     mul0018.json-0  ...                 none
# ...              ...  ...                  ...
# 3488  sng1147.json-2  ...                 none
# 3489  sng1150.json-0  ...                 none
# 3490  sng1150.json-1  ...                 none
# 3491  sng1150.json-2  ...                 none
# 3492  sng1150.json-3  ...                 none
#
# [3493 rows x 61 columns]

# %%
all_ = (pred_res[1] == pred_res[0]).all(axis=1)
shared = pred_res[0][all_]

# %%
# for idx, row in shared.iterrows(): 
#     print(row) 
#     print(row.keys())
#     break

# %%
from qual_analysis_utils import format_belief_state

# %%
shared_idx = set(shared['id'].tolist())
merged_idx = set(merged['id'].tolist() )
no_overlap = shared_idx.union(merged_idx) - shared_idx.intersection(merged_idx)

# %%
len(no_overlap), no_overlap
# Out:
# (10,
#  {'mul0818.json-4',
#   'mul0818.json-5',
#   'mul1678.json-0',
#   'mul1678.json-1',
#   'sng0317.json-1',
#   'sng0317.json-2',
#   'sng0317.json-3',
#   'sng0317.json-4',
#   'sng0317.json-5',
#   'sng0317.json-6'})

# %%
print(len(merged), len(shared))
# Out:
# 3493 3483

# %%
for did in no_overlap: 
    row1 = pred_res[0][pred_res[0].id == did][0]
    row2 = pred_res[1][pred_res[1].id == did][0]

    gold_bs1, pred_bs1 = format_belief_state(row1)
    gold_bs2, pred_bs2 = format_belief_state(row2)

    assert gold_bs1 == gold_bs2, (gold_bs1, gold_bs2)

    print(pred_bs1, pred_bs2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda/envs/trippy/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda/envs/trippy/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda/envs/trippy/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
